# %%
import pandas as pd

# %%
df= pd.read_csv('data_linear.csv')
df
# Out:
#       age     sex     bmi  children  smoker     region      charges
# 0      19  female  27.900         0    True  southwest  16884.92400
# 1      18    male  33.770         1   False  southeast   1725.55230
# 2      28    male  33.000         3   False  southeast   4449.46200
# 3      33    male  22.705         0   False  northwest  21984.47061
# 4      32    male  28.880         0   False  northwest   3866.85520
# ...   ...     ...     ...       ...     ...        ...          ...
# 1333   50    male  30.970         3   False  northwest  10600.54830
# 1334   18  female  31.920         0   False  northeast   2205.98080
# 1335   18  female  36.850         0   False  southeast   1629.83350
# 1336   21  female  25.800         0   False  southwest   2007.94500
# 1337   61  female  29.070         0    True  northwest  29141.36030
#
# [1338 rows x 7 columns]

# %%
X = df[['age', 'bmi', 'children']]
y = df['charges']

# %%
import statsmodels.api as sm
X = sm.add_constant(X)
ols_model = sm.OLS(y, X)
fitted_model = ols_model.fit()
fitted_model.params
fitted_model.summary()
# Out:
# C:\Users\deepa\anaconda3\lib\site-packages\statsmodels\tsa\tsatools.py:142: FutureWarning: In a future version of pandas all arguments of concat except for the argument 'objs' will be keyword-only
#   x = pd.concat(x[::order], 1)
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                charges   R-squared:                       0.121
# Model:                            OLS   Adj. R-squared:                  0.119
# Method:                 Least Squares   F-statistic:                     61.48
# Date:                Wed, 02 Mar 2022   Prob (F-statistic):           3.12e-37
# Time:                        19:47:04   Log-Likelihood:                -14391.
# No. Observations:                1338   AIC:                         2.879e+04
# Df Residuals:                    1334   BIC:                         2.881e+04
# Df Model:                           3
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const      -7231.1956   1766.233     -4.094      0.000   -1.07e+04   -3766.298
# age          239.1194     22.280     10.733      0.000     195.413     282.826
# bmi          343.1406     51.705      6.636      0.000     241.708     444.573
# children     541.9267    258.040      2.100      0.036      35.718    1048.135
# ==============================================================================
# Omnibus:                      323.072   Durbin-Watson:                   2.012
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              596.428
# Skew:                           1.513   Prob(JB):                    3.07e-130
# Kurtosis:                       4.241   Cond. No.                         292.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
x = df[['age', 'bmi']]

# %%
x = sm.add_constant(x)
ols_model = sm.OLS(y, x)
fitted_model = ols_model.fit()
fitted_model.params
fitted_model.summary()
# Out:
# C:\Users\deepa\anaconda3\lib\site-packages\statsmodels\tsa\tsatools.py:142: FutureWarning: In a future version of pandas all arguments of concat except for the argument 'objs' will be keyword-only
#   x = pd.concat(x[::order], 1)
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                charges   R-squared:                       0.119
# Model:                            OLS   Adj. R-squared:                  0.117
# Method:                 Least Squares   F-statistic:                     89.79
# Date:                Wed, 02 Mar 2022   Prob (F-statistic):           2.59e-37
# Time:                        19:51:38   Log-Likelihood:                -14393.
# No. Observations:                1338   AIC:                         2.879e+04
# Df Residuals:                    1335   BIC:                         2.881e+04
# Df Model:                           2
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const      -6741.9131   1753.036     -3.846      0.000   -1.02e+04   -3302.908
# age          241.0492     22.289     10.815      0.000     197.324     284.775
# bmi          344.0664     51.770      6.646      0.000     242.508     445.625
# ==============================================================================
# Omnibus:                      319.506   Durbin-Watson:                   2.010
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              585.573
# Skew:                           1.504   Prob(JB):                    6.99e-128
# Kurtosis:                       4.208   Cond. No.                         289.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """
